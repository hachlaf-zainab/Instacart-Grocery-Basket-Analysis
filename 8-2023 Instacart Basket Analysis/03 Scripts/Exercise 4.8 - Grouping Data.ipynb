# %% [markdown]
# # 4.8: Grouping Data & Aggregating Variables

# %% [markdown]
# ## This notebook contains
# 1. Import data
# 2. Grouping data

# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 01. Import Data

# %%
# Set folder path
path = r'C:\Users\hachl\Downloads\4.3_orders_products\02 Data\Prepared Data'

# %%
# Import the merged data pickle file
ords_prods_merge = pd.read_pickle(os.path.join(path, 'updated_data.pkl'))

# %%
# Create subset

df = ords_prods_merge[:1000000]

# %%
# Check shape of subset
df.shape
# Out:
# (1000000, 19)

# %%
# Check overview of subset
df.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_last_order  product_id  add_to_cart_order  reordered  \
# 0                    NaN         196                  1          0
# 1                   15.0         196                  1          1
# 2                   21.0         196                  1          1
# 3                   29.0         196                  1          1
# 4                   28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge    price_range_loc  \
# 0         Soda        77              7     9.0   both  Mid-range product
# 1         Soda        77              7     9.0   both  Mid-range product
# 2         Soda        77              7     9.0   both  Mid-range product
# 3         Soda        77              7     9.0   both  Mid-range product
# 4         Soda        77              7     9.0   both  Mid-range product
#
#      busiest_day    busiest_days    busiest_hour   busiest_hours
# 0  Regularly day  Regularly busy  Average orders  Average orders
# 1  Regularly day    Slowest days  Average orders  Average orders
# 2  Regularly day    Slowest days     Most orders     Most orders
# 3      Least day    Slowest days  Average orders  Average orders
# 4      Least day    Slowest days     Most orders     Most orders

# %% [markdown]
# # 02. Grouping Data

# %%
# Group the data based on the 'product_name' variable

df.groupby('product_name')

# %%
# Find the average number of orders per user for each department ID --> Group the data by department ID and apply aggregation function to get the mean of order number

df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 4                18.825780
# 7                17.472355
# 13               17.993423
# 14               19.246334
# 16               19.463012
# 17               11.294069
# 19               19.305237
# 20               17.599636

# %% [markdown]
# ### This shows the best and lowest selling departments: for example, produce(4) sells considerably more on average than household goods(17).

# %%
# Double check via second method

df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 4     18.825780
# 7     17.472355
# 13    17.993423
# 14    19.246334
# 16    19.463012
# 17    11.294069
# 19    19.305237
# 20    17.599636
# Name: order_number, dtype: float64

# %%
# Performing Multiple Aggregations to find the mean, minimum and maximum values

df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 4                18.825780   1  99
# 7                17.472355   1  99
# 13               17.993423   1  99
# 14               19.246334   1  99
# 16               19.463012   1  99
# 17               11.294069   1  98
# 19               19.305237   1  99
# 20               17.599636   1  99

# %% [markdown]
# #### Locate loyalty customers at Instacart so that the business strategy team can employ some kind of bonus point program for them.

# %%
# Step 1: create a new column containing the max. of the “order_number” column

ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %% [markdown]
# #### Explanation: new column called 'max_order' is created, which will contain the maximum order number for each user - the dataframe is grouped by the “user_id” column and then the transform() function is applied on the 'order_number' column with the np.max argument  to transform the ‘order_number’ column by applying the max function from the NumPy library.

# %%
# Check ouput
ords_prods_merge.head(15)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2398795        1             2                   3                  7
# 2     473747        1             3                   3                 12
# 3    2254736        1             4                   4                  7
# 4     431534        1             5                   4                 15
# 5    3367565        1             6                   2                  7
# 6     550135        1             7                   1                  9
# 7    3108588        1             8                   1                 14
# 8    2295261        1             9                   1                 16
# 9    2550362        1            10                   4                  8
# 10   2968173       15            15                   1                  9
# 11   1870022       15            17                   2                 16
# 12   1911383       15            18                   2                 11
# 13   2715276       15            21                   1                  9
# 14    487368       15            22                   1                 10
#
#     days_since_last_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
# 5                    19.0         196                  1          1
# 6                    20.0         196                  1          1
# 7                    14.0         196                  2          1
# 8                     0.0         196                  4          1
# 9                    30.0         196                  1          1
# 10                    7.0         196                  2          0
# 11                    8.0         196                  6          1
# 12                    7.0         196                  1          1
# 13                    7.0         196                  1          1
# 14                   14.0         196                  1          1
#
#    product_name  aisle_id  department_id  prices _merge    price_range_loc  \
# 0          Soda        77              7     9.0   both  Mid-range product
# 1          Soda        77              7     9.0   both  Mid-range product
# 2          Soda        77              7     9.0   both  Mid-range product
# 3          Soda        77              7     9.0   both  Mid-range product
# 4          Soda        77              7     9.0   both  Mid-range product
# 5          Soda        77              7     9.0   both  Mid-range product
# 6          Soda        77              7     9.0   both  Mid-range product
# 7          Soda        77              7     9.0   both  Mid-range product
# 8          Soda        77              7     9.0   both  Mid-range product
# 9          Soda        77              7     9.0   both  Mid-range product
# 10         Soda        77              7     9.0   both  Mid-range product
# 11         Soda        77              7     9.0   both  Mid-range product
# 12         Soda        77              7     9.0   both  Mid-range product
# 13         Soda        77              7     9.0   both  Mid-range product
# 14         Soda        77              7     9.0   both  Mid-range product
#
#       busiest_day    busiest_days    busiest_hour   busiest_hours  max_order
# 0   Regularly day  Regularly busy  Average orders  Average orders         10
# 1   Regularly day    Slowest days  Average orders  Average orders         10
# 2   Regularly day    Slowest days     Most orders     Most orders         10
# 3       Least day    Slowest days  Average orders  Average orders         10
# 4       Least day    Slowest days     Most orders     Most orders         10
# 5   Regularly day  Regularly busy  Average orders  Average orders         10
# 6   Regularly day    Busiest days     Most orders     Most orders         10
# 7   Regularly day    Busiest days     Most orders     Most orders         10
# 8   Regularly day    Busiest days     Most orders     Most orders         10
# 9       Least day    Slowest days  Average orders  Average orders         10
# 10  Regularly day    Busiest days     Most orders     Most orders         22
# 11  Regularly day  Regularly busy     Most orders     Most orders         22
# 12  Regularly day  Regularly busy     Most orders     Most orders         22
# 13  Regularly day    Busiest days     Most orders     Most orders         22
# 14  Regularly day    Busiest days     Most orders     Most orders         22

# %%
# Remove row number limit

pd.options.display.max_rows = None

# %%
# Check first 100 rows of df
ords_prods_merge.head(100)

# %% [markdown]
# #### Expanding the number of rows allows me to check whether the aggregation procedure was successfull. I will now delete the ouput to manage the notebook size

# %%
# Step 2: create a second column containing a flag designating whether a customer is “loyal” or not

ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
# Print the frequency of the new 'loyalty_flag' column using the value_counts() function

ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: count, dtype: int64

# %%
# Check output

ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].tail(60)
# Out:
#           user_id      loyalty_flag  order_number
# 32404799   183369  Regular customer            18
# 32404800   183369  Regular customer            26
# 32404801   183867    Loyal customer            19
# 32404802   185887      New customer             1
# 32404803   186019  Regular customer            10
# 32404804   198888  Regular customer            34
# 32404805   186019  Regular customer            14
# 32404806   186227    Loyal customer            17
# 32404807   186321      New customer             4
# 32404808   186870  Regular customer            17
# 32404809   186870  Regular customer            19
# 32404810   186419    Loyal customer            12
# 32404811   186419    Loyal customer            15
# 32404812   187144    Loyal customer            17
# 32404813   188105      New customer             1
# 32404814   188274  Regular customer            10
# 32404815   189140      New customer             2
# 32404816   190603  Regular customer            15
# 32404817   201296  Regular customer             1
# 32404818   191198    Loyal customer            37
# 32404819   191198    Loyal customer            67
# 32404820   198258  Regular customer            14
# 32404821   191406    Loyal customer             4
# 32404822   191508  Regular customer             5
# 32404823   196973  Regular customer            11
# 32404824   192494      New customer             3
# 32404825   192711  Regular customer            21
# 32404826   192711  Regular customer            22
# 32404827   192711  Regular customer            24
# 32404828   192777  Regular customer             1
# 32404829   193840      New customer             3
# 32404830   194078  Regular customer             4
# 32404831   202763  Regular customer            27
# 32404832   194639    Loyal customer            25
# 32404833   196040  Regular customer             9
# 32404834   196359      New customer             2
# 32404835   197349  Regular customer             1
# 32404836   197459  Regular customer             2
# 32404837   198107  Regular customer             2
# 32404838   198107  Regular customer             4
# 32404839   200351  Regular customer             5
# 32404840   205587      New customer             1
# 32404841   200463      New customer             2
# 32404842   203389  Regular customer            16
# 32404843   202557  Regular customer             1
# 32404844   202557  Regular customer             4
# 32404845   202557  Regular customer             6
# 32404846   202557  Regular customer             8
# 32404847   202557  Regular customer             9
# 32404848   202557  Regular customer            11
# 32404849   202557  Regular customer            12
# 32404850   202557  Regular customer            13
# 32404851   202557  Regular customer            14
# 32404852   202557  Regular customer            15
# 32404853   202557  Regular customer            16
# 32404854   202557  Regular customer            17
# 32404855   202557  Regular customer            18
# 32404856   203436      New customer             1
# 32404857   203436      New customer             2
# 32404858   205420  Regular customer             1
